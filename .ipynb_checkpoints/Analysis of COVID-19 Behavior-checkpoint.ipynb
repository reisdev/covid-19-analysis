# %%
from covid import COVID

# %%
dataset = COVID()

# %%
dataset.plot_deaths("Brazil","United States")
# Out:
# location    Brazil  United States
# date
# 2020-03-01     NaN            1.0
# 2020-03-02     NaN            2.0
# 2020-03-03     NaN            6.0
# 2020-03-04     NaN            9.0
# 2020-03-05     NaN           11.0
# 2020-03-06     NaN           12.0
# 2020-03-07     NaN           14.0
# 2020-03-08     NaN           17.0
# 2020-03-09     NaN           21.0
# 2020-03-10     NaN           26.0
# 2020-03-11     NaN           28.0
# 2020-03-12     NaN           30.0
# 2020-03-13     NaN           40.0
# 2020-03-14     NaN           47.0
# 2020-03-15     NaN           57.0
# 2020-03-16     NaN           69.0
# 2020-03-17     NaN           85.0
# 2020-03-18     1.0          108.0
# 2020-03-19     4.0          150.0
# 2020-03-20     6.0          150.0
# 2020-03-21    11.0          260.0

# %%
dataset.plot_total_cases("Brazil")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\matheus\.virtualenvs\covid-19-analysis-lloo4h2y\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'total_cases'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-ca5fd5a6aa9d> in <module>
# ...

# %%
dataset.get_status("Brazil")
